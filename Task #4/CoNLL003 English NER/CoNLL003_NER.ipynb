# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk import pos_tag
import re
import spacy
import warnings
import string
warnings.filterwarnings('ignore')

# nltk.download('average_perceptron_tagger')
# nltk.download('punkt_tab')

# %% [markdown]
# # Data Loading

# %%
def read_data(path):
    sentences = []
    sentence = []
    with open(path, encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:  # sentence boundary
                if sentence:
                    sentences.append(sentence)
                    sentence = []
                continue
            if line.startswith("-DOCSTART-"):
                continue
            parts = line.split()
            word, pos, chunk, ner = parts
            sentence.append({"word": word, "pos": pos, "chunk": chunk, "ner": ner})
    if sentence:
        sentences.append(sentence)
    return sentences # Returns a list of sentences, inside each sentence a list of dictionaries for each word.

# %%
train_sentences = read_data("Dataset/train.txt")
test_sentences  = read_data("Dataset/test.txt")
valid_sentences = read_data("Dataset/valid.txt")

# I think we'll perform NER on the test sentences

# %%
full_train_sentences = ' '.join(word for sentence in train_sentences for word in [d['word'] for d in sentence])

# %% [markdown]
# # Model-Based NER

# %%
# Using (probably) largest model.
nlp = spacy.load('en_core_web_trf')
nlp.max_length = 1100000
doc = nlp(full_train_sentences)
spacy.displacy.render(nlp(full_train_sentences[:2000]), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  rejects
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  call to boycott
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lamb .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Blackburn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRUSSELS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1996-08-
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 22
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The European Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  it disagreed with
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  advice to consumers to shun
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lamb until scientists determine whether mad cow disease can be transmitted to sheep .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  's representative to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Union 's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  veterinary committee
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Werner Zwingmann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  consumers should buy sheepmeat from countries other than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  until the scientific advice was clearer . &quot; We do n't support any such recommendation because we do n't see any grounds for it , &quot; the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  's chief spokesman
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nikolaus van der Pas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told a news briefing . He said further scientific study was required and if it was found that action was needed it should be taken by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Union
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  . He said a proposal
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Farm Commissioner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franz Fischler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to ban sheep brains , spleens and spinal cords from the human and animal food chains was a highly specific and precautionary move to protect human health .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fischler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  proposed
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -wide measures after reports from
# <mark class="entity" style="background: #feca74

# %%
# Using small model
nlp_small = spacy.load('en_core_web_sm')
nlp_small.max_length = 1100000
doc_small = nlp_small(full_train_sentences)
spacy.displacy.render(nlp_small(full_train_sentences[:2000]), style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  rejects
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  call to boycott
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lamb .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Blackburn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  BRUSSELS
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1996-08-22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The European Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  it disagreed with
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  advice to consumers to shun
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lamb until scientists determine whether mad cow disease can be transmitted to sheep .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  's representative to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Union 's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  veterinary committee
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Werner Zwingmann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  consumers should buy sheepmeat from countries other than
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Britain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  until the scientific advice was clearer . &quot; We do n't support any such recommendation because we do n't see any grounds for it , &quot; the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  's chief spokesman
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nikolaus van der Pas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told a news briefing . He said further scientific study was required and if it was found that action was needed it should be taken by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Union
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  . He said a proposal
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU Farm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Commissioner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Franz Fischler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to ban sheep brains ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     spleens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and spinal cords from the human and animal food chains was a highly specific and precautionary move to protect human health .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fischler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  proposed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -wide measures after reports from
# <mark class="entity" style="background: #feca7

# %% [markdown]
# # Rule-Based NER

# %%
# Preparation for rule-based NER
train_sentences_tokenized = word_tokenize(full_train_sentences)
#tests_tokenized_no_puncutations = [words for words in train_sentences_tokenized if words not in string.punctuation]
tagged_train_data = pos_tag(train_sentences_tokenized)
tagged_train_data
# Out:
# [('EU', 'NNP'),
#  ('rejects', 'VBZ'),
#  ('German', 'JJ'),
#  ('call', 'NN'),
#  ('to', 'TO'),
#  ('boycott', 'VB'),
#  ('British', 'JJ'),
#  ('lamb', 'NN'),
#  ('.', '.'),
#  ('Peter', 'NNP'),
#  ('Blackburn', 'NNP'),
#  ('BRUSSELS', 'NNP'),
#  ('1996-08-22', 'CD'),
#  ('The', 'DT'),
#  ('European', 'JJ'),
#  ('Commission', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('it', 'PRP'),
#  ('disagreed', 'VBD'),
#  ('with', 'IN'),
#  ('German', 'JJ'),
#  ('advice', 'NN'),
#  ('to', 'TO'),
#  ('consumers', 'NNS'),
#  ('to', 'TO'),
#  ('shun', 'VB'),
#  ('British', 'JJ'),
#  ('lamb', 'NNS'),
#  ('until', 'IN'),
#  ('scientists', 'NNS'),
#  ('determine', 'VBP'),
#  ('whether', 'IN'),
#  ('mad', 'JJ'),
#  ('cow', 'JJ'),
#  ('disease', 'NN'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('transmitted', 'VBN'),
#  ('to', 'TO'),
#  ('sheep', 'VB'),
#  ('.', '.'),
#  ('Germany', 'NNP'),
#  ("'s", 'POS'),
#  ('representative', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ("'s", 'POS'),
#  ('veterinary', 'JJ'),
#  ('committee', 'NN'),
#  ('Werner', 'NNP'),
#  ('Zwingmann', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('consumers', 'NNS'),
#  ('should', 'MD'),
#  ('buy', 'VB'),
#  ('sheepmeat', 'NN'),
#  ('from', 'IN'),
#  ('countries', 'NNS'),
#  ('other', 'JJ'),
#  ('than', 'IN'),
#  ('Britain', 'NNP'),
#  ('until', 'IN'),
#  ('the', 'DT'),
#  ('scientific', 'JJ'),
#  ('advice', 'NN'),
#  ('was', 'VBD'),
#  ('clearer', 'JJR'),
#  ('.', '.'),
#  ('``', '``'),
#  ('We', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('support', 'VB'),
#  ('any', 'DT'),
#  ('such', 'JJ'),
#  ('recommendation', 'NN'),
#  ('because', 'IN'),
#  ('we', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('see', 'VB'),
#  ('any', 'DT'),
#  ('grounds', 'NNS'),
#  ('for', 'IN'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('``', '``'),
#  ('the', 'DT'),
#  ('Commission', 'NNP'),
#  ("'s", 'POS'),
#  ('chief', 'JJ'),
#  ('spokesman', 'NN'),
#  ('Nikolaus', 'NNP'),
#  ('van', 'NN'),
#  ('der', 'NN'),
#  ('Pas', 'NNP'),
#  ('told', 'VBD'),
#  ('a', 'DT'),
#  ('news', 'NN'),
#  ('briefing', 'NN'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  ('further', 'RBR'),
#  ('scientific', 'JJ'),
#  ('study', 'NN'),
#  ('was', 'VBD'),
#  ('required', 'VBN'),
#  ('and', 'CC'),
#  ('if', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('found', 'VBN'),
#  ('that', 'IN'),
#  ('action', 'NN'),
#  ('was', 'VBD'),
#  ('needed', 'VBN'),
#  ('it', 'PRP'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('taken', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('said', 'VBD'),
#  ('a', 'DT'),
#  ('proposal', 'NN'),
#  ('last', 'JJ'),
#  ('month', 'NN'),
#  ('by', 'IN'),
#  ('EU', 'NNP'),
#  ('Farm', 'NNP'),
#  ('Commissioner', 'NNP'),
#  ('Franz', 'NNP'),
#  ('Fischler', 'NNP'),
#  ('to', 'TO'),
#  ('ban', 'VB'),
#  ('sheep', 'JJ'),
#  ('brains', 'NNS'),
#  (',', ','),
#  ('spleens', 'NNS'),
#  ('and', 'CC'),
#  ('spinal', 'JJ'),
#  ('cords', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('human', 'NN'),
#  ('and', 'CC'),
#  ('animal', 'NN'),
#  ('food', 'NN'),
#  ('chains', 'NNS'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('highly', 'RB'),
#  ('specific', 'JJ'),
#  ('and', 'CC'),
#  ('precautionary', 'JJ'),
#  ('move', 'NN'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('human', 'JJ'),
#  ('health', 'NN'),
#  ('.', '.'),
#  ('Fischler', 'NNP'),
#  ('proposed', 'VBD'),
#  ('EU-wide', 'NNP'),
#  ('measures', 'NNS'),
#  ('after', 'IN'),
#  ('reports', 'NNS'),
#  ('from', 'IN'),
#  ('Britain', 'NNP'),
#  ('and', 'CC'),
#  ('France', 'NNP'),
#  ('that', 'IN'),
#  ('under', 'IN'),
#  ('laboratory', 'NN'),
#  ('conditions', 'NNS'),
#  ('sheep', 'NN'),
#  ('could', 'MD'),
#  ('contract', 'NN'),
#  ('Bovine', 'NNP'),
#  ('Spongiform', 'NNP'),
#  ('Encephalopathy', 'NNP'),
#  ('(', '('),
#  ('BSE', 'NNP'),
#  (')', ')'),
#  ('--', ':'),
#  ('mad', 'JJ'),
#  ('cow', 'JJ'),
#  ('disease', 'NN'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('Fischler', 'NNP'),
#  ('agreed', 'VBD'),
#  ('to', 'TO'),
#  ('review', 'VB'),
#  ('his', 'PRP$'),
#  ('proposal', 'NN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('EU', 'NNP'),
#  ("'s", 'POS'),
#  ('standing', 'NN'),
#  ('veterinary', 'JJ'),
#  ('committee', 'NN'),
#  (',', ','),
#  ('mational', 'JJ'),
#  ('animal', 'JJ'),
#  ('health', 'NN'),
#  ('officials', 'NNS'),
#  (',', ','),
#  ('questioned', 'VBN'),
#  ('if', 'IN'),
#  ('such', 'JJ'),
#  ('action', 'NN'),
#  ('was', 'VBD'),
#  ('justified', 'VBN'),
#  ('as', 'IN'),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('only', 'RB'),
#  ('a', 'DT'),
#  ('slight', 'JJ'),
#  ('risk', 'NN'),
#  ('to', 'TO'),
#  ('human', 'JJ'),
#  ('health', 'NN'),
#  ('.', '.'),
#  ('Spanish', 'JJ'),
#  ('Farm', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Loyola', 'NNP'),
#  ('de', 'FW'),
#  ('Palacio', 'NNP'),
#  ('had', 'VBD'),
#  ('earlier', 'RBR'),
#  ('accused', 'VBN'),
#  ('Fischler', 'NNP'),
#  ('at', 'IN'),
#  ('an', 'DT'),
#  ('EU', 'NNP'),
#  ('farm', 'NN'),
#  ('ministers', 'NNS'),
#  ("'", 'POS'),
#  ('meeting', 'NN'),
#  ('of', 'IN'),
#  ('causing', 'VBG'),
#  ('unjustified', 'JJ'),
#  ('alarm', 'NN'),
#  ('through', 'IN'),
#  ('``', '``'),
#  ('dangerous', 'JJ'),
#  ('generalisation', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  ('.', '.'),
#  ('Only', 'RB'),
#  ('France', 'NNP'),
#  ('and', 'CC'),
#  ('Britain', 'NNP'),
#  ('backed', 'VBD'),
#  ('Fischler', 'NNP'),
#  ("'s", 'POS'),
#  ('proposal', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('EU', 'NNP'),
#  ("'s", 'POS'),
#  ('scientific', 'JJ'),
#  ('veterinary', 'NN'),
#  ('and', 'CC'),
#  ('multidisciplinary', 'JJ'),
#  ('committees', 'NNS'),
#  ('are', 'VBP'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('re-examine', 'VB'),
#  ('the', 'DT'),
#  ('issue', 'NN'),
#  ('early', 'RB'),
#  ('next', 'JJ'),
#  ('month', 'NN'),
#  ('and', 'CC'),
#  ('make', 'VB'),
#  ('recommendations', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('senior', 'JJ'),
#  ('veterinary', 'JJ'),
#  ('officials', 'NNS'),
#  ('.', '.'),
#  ('Sheep', 'NNP'),
#  ('have', 'VBP'),
#  ('long', 'RB'),
#  ('been', 'VBN'),
#  ('known', 'VBN'),
#  ('to', 'TO'),
#  ('contract', 'NN'),
#  ('scrapie', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('brain-wasting', 'JJ'),
#  ('disease', 'NN'),
#  ('similar', 'JJ'),
#  ('to', 'TO'),
#  ('BSE', 'NNP'),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('believed', 'VBN'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('transferred', 'VBN'),
#  ('to', 'TO'),
#  ('cattle', 'VB'),
#  ('through', 'IN'),
#  ('feed', 'NN'),
#  ('containing', 'VBG'),
#  ('animal', 'JJ'),
#  ('waste', 'NN'),
#  ('.', '.'),
#  ('British', 'JJ'),
#  ('farmers', 'NNS'),
#  ('denied', 'VBD'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('there', 'EX'),
#  ('was', 'VBD'),
#  ('any', 'DT'),
#  ('danger', 'NN'),
#  ('to', 'TO'),
#  ('human', 'JJ'),
#  ('health', 'NN'),
#  ('from', 'IN'),
#  ('their', 'PRP$'),
#  ('sheep', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('expressed', 'VBD'),
#  ('concern', 'NN'),
#  ('that', 'IN'),
#  ('German', 'JJ'),
#  ('government', 'NN'),
#  ('advice', 'NN'),
#  ('to', 'TO'),
#  ('consumers', 'NNS'),
#  ('to', 'TO'),
#  ('avoid', 'VB'),
#  ('British', 'JJ'),
#  ('lamb', 'NN'),
#  ('might', 'MD'),
#  ('influence', 'VB'),
#  ('consumers', 'NNS'),
#  ('across', 'IN'),
#  ('Europe', 'NNP'),
#  ('.', '.'),
#  ('``', '``'),
#  ('What', 'WP'),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('extremely', 'RB'),
#  ('careful', 'JJ'),
#  ('of', 'IN'),
#  ('is', 'VBZ'),
#  ('how', 'WRB'),
#  ('other', 'JJ'),
#  ('countries', 'NNS'),
#  ('are', 'VBP'),
#  ('going', 'VBG'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('Germany', 'NNP'),
#  ("'s", 'POS'),
#  ('lead', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('Welsh', 'NNP'),
#  ('National', 'NNP'),
#  ('Farmers', 'NNP'),
#  ("'", 'POS'),
#  ('Union', 'NNP'),
#  ('(', '('),
#  ('NFU', 'NNP'),
#  (')', ')'),
#  ('chairman', 'NN'),
#  ('John', 'NNP'),
#  ('Lloyd', 'NNP'),
#  ('Jones', 'NNP'),
#  ('said', 'VBD'),
#  ('on', 'IN'),
#  ('BBC', 'NNP'),
#  ('radio', 'NN'),
#  ('.', '.'),
#  ('Bonn', 'NNP'),
#  ('has', 'VBZ'),
#  ('led', 'VBN'),
#  ('efforts', 'NNS'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('public', 'JJ'),
#  ('health', 'NN'),
#  ('after', 'IN'),
#  ('consumer', 'NN'),
#  ('confidence', 'NN'),
#  ('collapsed', 'VBN'),
#  ('in', 'IN'),
#  ('March', 'NNP'),
#  ('after', 'IN'),
#  ('a', 'DT'),
#  ('British', 'JJ'),
#  ('report', 'NN'),
#  ('suggested', 'VBD'),
#  ('humans', 'NNS'),
#  ('could', 'MD'),
#  ('contract', 'NN'),
#  ('an', 'DT'),
#  ('illness', 'NN'),
#  ('similar', 'JJ'),
#  ('to', 'TO'),
#  ('mad', 'VB'),
#  ('cow', 'JJ'),
#  ('disease', 'NN'),
#  ('by', 'IN'),
#  ('eating', 'VBG'),
#  ('contaminated', 'VBN'),
#  ('beef', 'NN'),
#  ('.', '.'),
#  ('Germany', 'NNP'),
#  ('imported', 'VBD'),
#  ('47,600', 'CD'),
#  ('sheep', 'NN'),
#  ('from', 'IN'),
#  ('Britain', 'NNP'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  (',', ','),
#  ('nearly', 'RB'),
#  ('half', 'NN'),
#  ('of', 'IN'),
#  ('total', 'JJ'),
#  ('imports', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('brought', 'VBD'),
#  ('in', 'IN'),
#  ('4,275', 'CD'),
#  ('tonnes', 'NNS'),
#  ('of', 'IN'),
#  ('British', 'JJ'),
#  ('mutton', 'NN'),
#  (',', ','),
#  ('some', 'DT'),
#  ('10', 'CD'),
#  ('percent', 'NN'),
#  ('of', 'IN'),
#  ('overall', 'JJ'),
#  ('imports', 'NNS'),
#  ('.', '.'),
#  ('Rare', 'NNP'),
#  ('Hendrix', 'NNP'),
#  ('song', 'NN'),
#  ('draft', 'NN'),
#  ('sells', 'VBZ'),
#  ('for', 'IN'),
#  ('almost', 'RB'),
#  ('$', '$'),
#  ('17,000', 'CD'),
#  ('.', '.'),
#  ('LONDON', 'NNP'),
#  ('1996-08-22', 'JJ'),
#  ('A', 'NNP'),
#  ('rare', 'JJ'),
#  ('early', 'JJ'),
#  ('handwritten', 'NN'),
#  ('draft', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('song', 'NN'),
#  ('by', 'IN'),
#  ('U.S.', 'NNP'),
#  ('guitar', 'NN'),
#  ('legend', 'NN'),
#  ('Jimi', 'NNP'),
#  ('Hendrix', 'NNP'),
#  ('was', 'VBD'),
#  ('sold', 'VBN'),
#  ('for', 'IN'),
#  ('almost', 'RB'),
#  ('$', '$'),
#  ('17,000', 'CD'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('at', 'IN'),
#  ('an', 'DT'),
#  ('auction', 'NN'),
#  ('of', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('late', 'JJ'),
#  ('musician', 'NN'),
#  ("'s", 'POS'),
#  ('favourite', 'JJ'),
#  ('possessions', 'NNS'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('Florida', 'NNP'),
#  ('restaurant', 'NN'),
#  ('paid', 'VBD'),
#  ('10,925', 'CD'),
#  ('pounds', 'NNS'),
#  ('(', '('),
#  ('$', '$'),
#  ('16,935', 'CD'),
#  (')', ')'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('draft', 'NN'),
#  ('of', 'IN'),
#  ('``', '``'),
#  ('Ai', 'NNP'),
#  ("n't", 'RB'),
#  ('no', 'VBD'),
#  ('telling', 'VBG'),
#  ('``', '``'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('Hendrix', 'NNP'),
#  ('penned', 'VBD'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('piece', 'NN'),
#  ('of', 'IN'),
#  ('London', 'NNP'),
#  ('hotel', 'NN'),
#  ('stationery', 'NN'),
#  ('in', 'IN'),
#  ('late', 'JJ'),
#  ('1966', 'CD'),
#  ('.', '.'),
#  ('At', 'IN'),
#  ('the', 'DT'),
#  ('end', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('January', 'NNP'),
#  ('1967', 'CD'),
#  ('concert', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('English', 'NNP'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Nottingham', 'NNP'),
#  ('he', 'PRP'),
#  ('threw', 'VBD'),
#  ('the', 'DT'),
#  ('sheet', 'NN'),
#  ('of', 'IN'),
#  ('paper', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('audience', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('retrieved', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('fan', 'NN'),
#  ('.', '.'),
#  ('Buyers', 'NNS'),
#  ('also', 'RB'),
#  ('snapped', 'VBD'),
#  ('up', 'RB'),
#  ('16', 'CD'),
#  ('other', 'JJ'),
#  ('items', 'NNS'),
#  ('that', 'WDT'),
#  ('were', 'VBD'),
#  ('put', 'VBN'),
#  ('up', 'RP'),
#  ('for', 'IN'),
#  ('auction', 'NN'),
#  ('by', 'IN'),
#  ('Hendrix', 'NNP'),
#  ("'s", 'POS'),
#  ('former', 'JJ'),
#  ('girlfriend', 'NN'),
#  ('Kathy', 'NNP'),
#  ('Etchingham', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('lived', 'VBD'),
#  ('with', 'IN'),
#  ('him', 'PRP'),
#  ('from', 'IN'),
#  ('1966', 'CD'),
#  ('to', 'TO'),
#  ('1969', 'CD'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('included', 'VBD'),
#  ('a', 'DT'),
#  ('black', 'JJ'),
#  ('lacquer', 'NN'),
#  ('and', 'CC'),
#  ('mother', 'NN'),
#  ('of', 'IN'),
#  ('pearl', 'NN'),
#  ('inlaid', 'NN'),
#  ('box', 'NN'),
#  ('used', 'VBN'),
#  ('by', 'IN'),
#  ('Hendrix', 'NNP'),
#  ('to', 'TO'),
#  ('store', 'VB'),
#  ('his', 'PRP$'),
#  ('drugs', 'NNS'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('an', 'DT'),
#  ('anonymous', 'JJ'),
#  ('Australian', 'JJ'),
#  ('purchaser', 'NN'),
#  ('bought', 'VBD'),
#  ('for', 'IN'),
#  ('5,060', 'CD'),
#  ('pounds', 'NNS'),
#  ('(', '('),
#  ('$', '$'),
#  ('7,845', 'CD'),
#  (')', ')'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('guitarist', 'NN'),
#  ('died', 'VBD'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('drugs', 'NNS'),
#  ('overdose', 'RB'),
#  ('in', 'IN'),
#  ('1970', 'CD'),
#  ('aged', 'VBD'),
#  ('27', 'CD'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('says', 'VBZ'),
#  ('Taiwan', 'NNP'),
#  ('spoils', 'NNS'),
#  ('atmosphere', 'RB'),
#  ('for', 'IN'),
#  ('talks', 'NNS'),
#  ('.', '.'),
#  ('BEIJING', 'NNP'),
#  ('1996-08-22', 'JJ'),
#  ('China', 'NNP'),
#  ('on', 'IN'),
#  ('Thursday', 'NNP'),
#  ('accused', 'VBD'),
#  ('Taipei', 'NNP'),
#  ('of', 'IN'),
#  ('spoiling', 'VBG'),
#  ('the', 'DT'),
#  ('atmosphere', 'NN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('resumption', 'NN'),
#  ('of', 'IN'),
#  ('talks', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('Taiwan', 'NNP'),
#  ('Strait', 'NNP'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('visit', 'NN'),
#  ('to', 'TO'),
#  ('Ukraine', 'VB'),
#  ('by', 'IN'),
#  ('Taiwanese', 'JJ'),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Lien', 'NNP'),
#  ('Chan', 'NNP'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('that', 'WDT'),
#  ('infuriated', 'VBD'),
#  ('Beijing', 'NNP'),
#  ('.', '.'),
#  ('Speaking', 'VBG'),
#  ('only', 'JJ'),
#  ('hours', 'NNS'),
#  ('after', 'IN'),
#  ('Chinese', 'JJ'),
#  ('state', 'NN'),
#  ('media', 'NNS'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('was', 'VBD'),
#  ('right', 'JJ'),
#  ('to', 'TO'),
#  ('engage', 'VB'),
#  ('in', 'IN'),
#  ('political', 'JJ'),
#  ('talks', 'NNS'),
#  ('with', 'IN'),
#  ('Taiwan', 'NNP'),
#  (',', ','),
#  ('Foreign', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('spokesman', 'NN'),
#  ('Shen', 'NNP'),
#  ('Guofang', 'NNP'),
#  ('told', 'VBD'),
#  ('Reuters', 'NNS'),
#  (':', ':'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('necessary', 'JJ'),
#  ('atmosphere', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('opening', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('talks', 'NNS'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('disrupted', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('Taiwan', 'NNP'),
#  ('authorities', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('State', 'NNP'),
#  ('media', 'NNS'),
#  ('quoted', 'VBD'),
#  ('China', 'NNP'),
#  ("'s", 'POS'),
#  ('top', 'JJ'),
#  ('negotiator', 'NN'),
#  ('with', 'IN'),
#  ('Taipei', 'NNP'),
#  (',', ','),
#  ('Tang', 'NNP'),
#  ('Shubei', 'NNP'),
#  (',', ','),
#  ('as', 'IN'),
#  ('telling', 'VBG'),
#  ('a', 'DT'),
#  ('visiting', 'VBG'),
#  ('group', 'NN'),
#  ('from', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('time', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('rivals', 'NNS'),
#  ('to', 'TO'),
#  ('hold', 'VB'),
#  ('political', 'JJ'),
#  ('talks', 'NNS'),
#  ('.', '.'),
#  ('``', '``'),
#  ('Now', 'RB'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('sides', 'NNS'),
#  ('to', 'TO'),
#  ('engage', 'VB'),
#  ('in', 'IN'),
#  ('political', 'JJ'),
#  ('talks', 'NNS'),
#  ('...', ':'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('end', 'VB'),
#  ('the', 'DT'),
#  ('state', 'NN'),
#  ('of', 'IN'),
#  ('hostility', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('Thursday', 'NNP'),
#  ("'s", 'POS'),
#  ('overseas', 'JJ'),
#  ('edition', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('People', 'NNP'),
#  ("'s", 'POS'),
#  ('Daily', 'NNP'),
#  ('quoted', 'VBD'),
#  ('Tang', 'NNP'),
#  ('as', 'IN'),
#  ('saying', 'VBG'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('foreign', 'JJ'),
#  ('ministry', 'NN'),
#  ("'s", 'POS'),
#  ('Shen', 'NNP'),
#  ('told', 'VBD'),
#  ('Reuters', 'NNPS'),
#  ('Television', 'NNP'),
#  ('in', 'IN'),
#  ('an', 'DT'),
#  ('interview', 'NN'),
#  ('he', 'PRP'),
#  ('had', 'VBD'),
#  ('read', 'VBN'),
#  ('reports', 'NNS'),
#  ('of', 'IN'),
#  ('Tang', 'NNP'),
#  ("'s", 'POS'),
#  ('comments', 'NNS'),
#  ('but', 'CC'),
#  ('gave', 'VBD'),
#  ('no', 'DT'),
#  ('details', 'NNS'),
#  ('of', 'IN'),
#  ('why', 'WRB'),
#  ('the', 'DT'),
#  ('negotiator', 'NN'),
#  ('had', 'VBD'),
#  ('considered', 'VBN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('right', 'NN'),
#  ('for', 'IN'),
#  ('talks', 'NNS'),
#  ('with', 'IN'),
#  ('Taiwan', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('Beijing', 'NNP'),
#  ('considers', 'VBZ'),
#  ('a', 'DT'),
#  ('renegade', 'JJ'),
#  ('province', 'NN'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('has', 'VBZ'),
#  ('long', 'RB'),
#  ('opposed', 'VBN'),
#  ('all', 'DT'),
#  ('Taipei', 'NNP'),
#  ('efforts', 'NNS'),
#  ('to', 'TO'),
#  ('gain', 'VB'),
#  ('greater', 'JJR'),
#  ('international', 'JJ'),
#  ('recognition', 'NN'),
#  (',', ','),
#  ('was', 'VBD'),
#  ('infuriated', 'VBN'),
#  ('by', 'IN'),
#  ('a', 'DT'),
#  ('visit', 'NN'),
#  ('to', 'TO'),
#  ('Ukraine', 'VB'),
#  ('this', 'DT'),
#  ('week', 'NN'),
#  ('by', 'IN'),
#  ('Taiwanese', 'JJ'),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Lien', 'NNP'),
#  ('.', '.'),
#  ('China', 'NNP'),
#  ('says', 'VBZ'),
#  ('time', 'NN'),
#  ('right', 'NN'),
#  ('for', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('talks', 'NNS'),
#  ('.', '.'),
#  ('BEIJING', 'NNP'),
#  ('1996-08-22', 'JJ'),
#  ('China', 'NNP'),
#  ('has', 'VBZ'),
#  ('said', 'VBD'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('time', 'NN'),
#  ('for', 'IN'),
#  ('political', 'JJ'),
#  ('talks', 'NNS'),
#  ('with', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('and', 'CC'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('rival', 'JJ'),
#  ('island', 'NN'),
#  ('should', 'MD'),
#  ('take', 'VB'),
#  ('practical', 'JJ'),
#  ('steps', 'NNS'),
#  ('towards', 'NNS'),
#  ('that', 'DT'),
#  ('goal', 'NN'),
#  ('.', '.'),
#  ('Consultations', 'NNS'),
#  ('should', 'MD'),
#  ('be', 'VB'),
#  ('held', 'VBN'),
#  ('to', 'TO'),
#  ('set', 'VB'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('format', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('talks', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('official', 'JJ'),
#  ('Xinhua', 'NNP'),
#  ('news', 'NN'),
#  ('agency', 'NN'),
#  ('quoted', 'VBD'),
#  ('Tang', 'NNP'),
#  ('Shubei', 'NNP'),
#  (',', ','),
#  ('executive', 'NN'),
#  ('vice', 'NN'),
#  ('chairman', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Association', 'NNP'),
#  ('for', 'IN'),
#  ('Relations', 'NNP'),
#  ('Across', 'IN'),
#  ('the', 'DT'),
#  ('Taiwan', 'NNP'),
#  ('Straits', 'NNP'),
#  (',', ','),
#  ('as', 'IN'),
#  ('saying', 'VBG'),
#  ('late', 'RB'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('.', '.'),
#  ('German', 'JJ'),
#  ('July', 'NNP'),
#  ('car', 'NN'),
#  ('registrations', 'NNS'),
#  ('up', 'RB'),
#  ('14.2', 'CD'),
#  ('pct', 'NNS'),
#  ('yr', 'RB'),
#  ('/', 'NNP'),
#  ('yr', 'NN'),
#  ('.', '.'),
#  ('FRANKFURT', 'NNP'),
#  ('1996-08-22', 'JJ'),
#  ('German', 'JJ'),
#  ('first-time', 'JJ'),
#  ('registrations', 'NNS'),
#  ('of', 'IN'),
#  ('motor', 'NN'),
#  ('vehicles', 'NNS'),
#  ('jumped', 'VBD'),
#  ('14.2', 'CD'),
#  ('percent', 'NN'),
#  ('in', 'IN'),
#  ('July', 'NNP'),
#  ('this', 'DT'),
#  ('year', 'NN'),
#  ('from', 'IN'),
#  ...]

# %%
import json

organizations = {pd.read_csv('Dictionaries/Organizations.csv')['orgLabel'].str}
locations = {val for entry in json.load(open("Dictionaries/Cities, Countries, States.json", encoding="utf-8")) for val in (entry["country_name"], entry["state_name"], entry["name"])}
person_first_names = {name.strip() for name in open("Dictionaries/First Names.txt", encoding="utf-8")}
person_last_names = set(pd.read_csv('Dictionaries/Last Names.csv')['name'].str.lower().str.capitalize())

def rule_based_ner(tagged_text):
    entities = []

    # Iteration index
    i = 0
    while i < len(tagged_text):
        token, pos = tagged_text[i]

        # Rule 1: Detect multi-word locations (e.g., "Washington D.C.")
        # This rule checks for a two-word capitalized sequence that is in our locations dictionary.
        if i + 1 < len(tagged_text):
            next_token, next_pos = tagged_text[i+1]
            candidate = f"{token} {next_token}"
            if pos == 'NNP' and next_pos == 'NNP' and candidate in locations:
                entities.append((candidate, "LOCATION"))
                i += 2
                continue

        # Rule 2: Detect person names
        # This rule checks for a two-word sequence of proper nouns (NNP)
        # where the first word is a known first name and the second is a known last name.
        if i + 1 < len(tagged_text):
            next_token, next_pos = tagged_text[i+1]
            if pos == 'NNP' and next_pos == 'NNP' and token in person_first_names and next_token in person_last_names:
                entities.append((f"{token} {next_token}", "PERSON"))
                i += 2
                continue

        # Rule 3: Detect organizations
        # This rule checks for a single capitalized word that is in our organizations dictionary.
        if pos == 'NNP' and token in organizations:
            entities.append((token, "ORGANIZATION"))
            i += 1
            continue

        # Rule 4: Detect single-word locations
        # This rule checks for a single capitalized word that is in our locations dictionary.
        # This should be checked after multi-word locations to avoid partial matches.
        if pos == 'NNP' and token in locations:
            entities.append((token, "LOCATION"))
            i += 1
            continue

        # Default increment
        i += 1

    return entities

# %%
found_entities = rule_based_ner(tagged_train_data)
print(found_entities)
# Out:
# [('Peter Blackburn', 'PERSON'), ('Germany', 'LOCATION'), ('Union', 'LOCATION'), ('Union', 'LOCATION'), ('France', 'LOCATION'), ('Loyola', 'LOCATION'), ('France', 'LOCATION'), ('Germany', 'LOCATION'), ('Welsh', 'LOCATION'), ('Union', 'LOCATION'), ('John Lloyd', 'PERSON'), ('Jones', 'LOCATION'), ('Bonn', 'LOCATION'), ('March', 'LOCATION'), ('Germany', 'LOCATION'), ('Jimi', 'LOCATION'), ('Florida', 'LOCATION'), ('London', 'LOCATION'), ('English', 'LOCATION'), ('Nottingham', 'LOCATION'), ('China', 'LOCATION'), ('Taiwan', 'LOCATION'), ('China', 'LOCATION'), ('Taipei', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Vice', 'LOCATION'), ('Lien Chan', 'PERSON'), ('Beijing', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Taiwan', 'LOCATION'), ('China', 'LOCATION'), ('Taipei', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Beijing', 'LOCATION'), ('China', 'LOCATION'), ('Taipei', 'LOCATION'), ('Vice', 'LOCATION'), ('China', 'LOCATION'), ('Taiwan', 'LOCATION'), ('China', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Taiwan', 'LOCATION'), ('Federal', 'LOCATION'), ('Ford', 'LOCATION'), ('Athens', 'LOCATION'), ('Toronto', 'LOCATION'), ('London', 'LOCATION'), ('London', 'LOCATION'), ('Syria', 'LOCATION'), ('Lloyds', 'LOCATION'), ('Lloyds', 'LOCATION'), ('Israel', 'LOCATION'), ('Syria', 'LOCATION'), ('Colleen Siegel', 'PERSON'), ('Israel', 'LOCATION'), ('Syria', 'LOCATION'), ('Israel', 'LOCATION'), ('Washington', 'LOCATION'), ('Syria', 'LOCATION'), ('Israel Radio', 'PERSON'), ('Damascus', 'LOCATION'), ('Washington', 'LOCATION'), ('Egypt', 'LOCATION'), ('Israel', 'LOCATION'), ('Syria', 'LOCATION'), ('Washington', 'LOCATION'), ('Damascus', 'LOCATION'), ('Syria', 'LOCATION'), ('Israel', 'LOCATION'), ('Damascus', 'LOCATION'), ('Israel', 'LOCATION'), ('David Levy', 'PERSON'), ('Israel Radio', 'PERSON'), ('Benjamin', 'LOCATION'), ('Israel', 'LOCATION'), ('Syria', 'LOCATION'), ('Middle', 'LOCATION'), ('East', 'LOCATION'), ('Damascus', 'LOCATION'), ('Syria', 'LOCATION'), ('Israel', 'LOCATION'), ('Israel', 'LOCATION'), ('Damascus', 'LOCATION'), ('Israel', 'LOCATION'), ('Syria', 'LOCATION'), ('Cairo', 'LOCATION'), ('Moscow', 'LOCATION'), ('Libya', 'LOCATION'), ('Libya', 'LOCATION'), ('Libya', 'LOCATION'), ('Tripoli', 'LOCATION'), ('Poland', 'LOCATION'), ('Libya', 'LOCATION'), ('Libya', 'LOCATION'), ('Baghdad', 'LOCATION'), ('Hassan', 'LOCATION'), ('Iraq', 'LOCATION'), ('Iran', 'LOCATION'), ('Iraq', 'LOCATION'), ('Baghdad', 'LOCATION'), ('Kurdistan', 'LOCATION'), ('Iran', 'LOCATION'), ('Hassan Rastegar', 'PERSON'), ('Iran', 'LOCATION'), ('Kurdistan', 'LOCATION'), ('Iran', 'LOCATION'), ('Iraq', 'LOCATION'), ('Baghdad', 'LOCATION'), ('Iran', 'LOCATION'), ('Union', 'LOCATION'), ('Kurdistan', 'LOCATION'), ('Iraq', 'LOCATION'), ('Kurdistan', 'LOCATION'), ('Iraq', 'LOCATION'), ('Kuwait', 'LOCATION'), ('Gulf', 'LOCATION'), ('Iran', 'LOCATION'), ('Turkey', 'LOCATION'), ('Iraq', 'LOCATION'), ('Turkey', 'LOCATION'), ('Baghdad', 'LOCATION'), ('Israel', 'LOCATION'), ('Arafat', 'LOCATION'), ('West', 'LOCATION'), ('Israel', 'LOCATION'), ('Arafat', 'LOCATION'), ('West', 'LOCATION'), ('Arafat', 'LOCATION'), ('West', 'LOCATION'), ('Abu', 'LOCATION'), ('Arafat', 'LOCATION'), ('West', 'LOCATION'), ('Ramallah', 'LOCATION'), ('Gaza', 'LOCATION'), ('Israel', 'LOCATION'), ('Benjamin', 'LOCATION'), ('Ramallah', 'LOCATION'), ('Arafat', 'LOCATION'), ('Arafat', 'LOCATION'), ('Bridge', 'LOCATION'), ('Jordan', 'LOCATION'), ('West', 'LOCATION'), ('Abu', 'LOCATION'), ('Arafat', 'LOCATION'), ('West', 'LOCATION'), ('Israel', 'LOCATION'), ('Gaza', 'LOCATION'), ('Arafat', 'LOCATION'), ('Gaza', 'LOCATION'), ('Arafat', 'LOCATION'), ('Gaza', 'LOCATION'), ('West', 'LOCATION'), ('Arafat', 'LOCATION'), ('Gaza', 'LOCATION'), ('Ramallah', 'LOCATION'), ('Arafat', 'LOCATION'), ('Israel', 'LOCATION'), ('West', 'LOCATION'), ('Benjamin', 'LOCATION'), ('Hilary Gush', 'PERSON'), ('Arab', 'LOCATION'), ('Afghanistan', 'LOCATION'), ('Abu Dhabi', 'LOCATION'), ('Afghanistan', 'LOCATION'), ('Sharjah', 'LOCATION'), (' ...

# %%
ner_results_rulebased = pd.DataFrame(found_entities, columns=['Identified', 'Entity'])
ner_results_rulebased.head()
# Out:
#         Identified    Entity
# 0  Peter Blackburn    PERSON
# 1          Germany  LOCATION
# 2            Union  LOCATION
# 3            Union  LOCATION
# 4           France  LOCATION

# %%
ner_results_rulebased['Entity'].value_counts(normalize=True)
# Out:
# Entity
# LOCATION    0.828451
# PERSON      0.171549
# Name: proportion, dtype: float64

# %%
ner_results_large_spacy = pd.DataFrame([(e.label_, e.text) for e in doc.ents], columns=['Entity', 'Identified'])
ner_results_large_spacy.head()
# Out:
#    Entity       Identified
# 0     ORG               EU
# 1    NORP           German
# 2    NORP          British
# 3  PERSON  Peter Blackburn
# 4     GPE         BRUSSELS

# %%
ner_results_large_spacy['Entity'].value_counts(normalize=True)
# Out:
# Entity
# GPE            0.198610
# PERSON         0.190622
# CARDINAL       0.157352
# ORG            0.139554
# DATE           0.136274
# NORP           0.058804
# ORDINAL        0.032990
# MONEY          0.019984
# TIME           0.012977
# QUANTITY       0.012333
# EVENT          0.012108
# PERCENT        0.010427
# FAC            0.006306
# LOC            0.005325
# PRODUCT        0.003924
# WORK_OF_ART    0.001429
# LAW            0.000561
# LANGUAGE       0.000420
# Name: proportion, dtype: float64

# %%
ner_results_small_spacy = pd.DataFrame([(e.label_, e.text) for e in doc_small.ents], columns=['Entity', 'Identified'])
ner_results_small_spacy.head()
# Out:
#    Entity       Identified
# 0     ORG               EU
# 1    NORP           German
# 2    NORP          British
# 3  PERSON  Peter Blackburn
# 4    DATE       1996-08-22

# %%
ner_results_small_spacy['Entity'].value_counts(normalize=True)
# Out:
# Entity
# DATE           0.185113
# GPE            0.174123
# PERSON         0.170817
# CARDINAL       0.167808
# ORG            0.127718
# NORP           0.059451
# ORDINAL        0.029398
# MONEY          0.018348
# QUANTITY       0.012808
# TIME           0.012450
# PERCENT        0.009889
# PRODUCT        0.009740
# LOC            0.006463
# EVENT          0.005272
# FAC            0.005004
# WORK_OF_ART    0.002770
# LAW            0.001996
# LANGUAGE       0.000834
# Name: proportion, dtype: float64
